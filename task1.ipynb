# %%
from langchain import PromptTemplate
import json

template = '''Hello! I'm your AI sales assistant, and I'm here to assist you with your loan application. Let's gather some information to get started:

1. Are you interested in applying for a loan? (Yes/No){loan_interest}
2. If yes, what is the desired loan amount?{loan_amount}
3. What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL){loan_purpose}
4. Do you file Income Tax Returns (ITR)? (Yes/No){itr_status}
5. If yes, could you provide your latest ITR details?{itr_details}
6. What is your profession?{profession}
   - If Business, could you provide the annual turnover based on GST records?{annual_turnover}
   - If Salaried, what is your annual salary as per your salary slips?{annual_salary}

Thank you for providing this information. Once we have all the necessary details, we'll proceed with your loan application. If you have any additional questions or if there's anything else you'd like to discuss, feel free to let me know.

To end our conversation, please type "Goodbye" when you're ready to conclude. Thank you!'''

sales_agent_prompt = PromptTemplate(
    input_variables=["loan_interest", "loan_amount", "loan_purpose",
                      "itr_status", "profession", "itr_details","annual_turnover", "annual_salary"],
    template=template,
)

def simulate_conversation():
    user_responses = {}
    for variable in sales_agent_prompt.input_variables:
        user_responses[variable] = input(f"{variable.replace('_', ' ').title()}: ").strip()

    return user_responses

def main():
    print("Simulating conversation with the AI sales assistant:")
    user_input = simulate_conversation()

    # Format the user input for the sales agent prompt
    formatted_input = {key: f'{{{key}}}' for key in sales_agent_prompt.input_variables}
    formatted_input.update(user_input)

    # Use the formatted input to create the final conversation
    conversation = sales_agent_prompt.format(**formatted_input)

    # Print the final conversation
    print("\nFinal Conversation:")
    print(conversation)

    # Extract information in the form of JSON
    loan_info_json = {
        "loan_interest": user_input["loan_interest"],
        "loan_amount": int(user_input["loan_amount"]),
        "loan_purpose": user_input["loan_purpose"],
        "itr_status": user_input["itr_status"],
        "profession": user_input["profession"],
        "annual_turnover": int(user_input["annual_turnover"]),
        "annual_salary": int(user_input["annual_salary"]) if user_input["annual_salary"].lower() != 'none' else None
    }

    # Print the JSON information
    print("\nJSON Output:")
    print(json.dumps(loan_info_json, indent=4))

if __name__ == "__main__":
    main()
# Out:
# Simulating conversation with the AI sales assistant:
#
# Final Conversation:
# Hello! I'm your AI sales assistant, and I'm here to assist you with your loan application. Let's gather some information to get started:
#
# 1. Are you interested in applying for a loan? (Yes/No)yes
# 2. If yes, what is the desired loan amount?156415
# 3. What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL)car
# 4. Do you file Income Tax Returns (ITR)? (Yes/No)yes
# 5. If yes, could you provide your latest ITR details?50000
# 6. What is your profession?student
#    - If Business, could you provide the annual turnover based on GST records?5000
#    - If Salaried, what is your annual salary as per your salary slips?55000
#
# Thank you for providing this information. Once we have all the necessary details, we'll proceed with your loan application. If you have any additional questions or if there's anything else you'd like to discuss, feel free to let me know.
#
# ...

# %%
import json

def simulate_conversation():
    user_responses = {}

    # Ask questions and store user responses
    user_responses["loan_interest"] = input("Are you interested in applying for a loan? (Yes/No) ").strip().lower()
    user_responses["loan_amount"] = input("If yes, what is the desired loan amount? ")
    user_responses["loan_purpose"] = input("What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL) ").strip().upper()
    user_responses["itr_status"] = input("Do you file Income Tax Returns (ITR)? (Yes/No) ").strip().lower()

    if user_responses["itr_status"] == "yes":
        user_responses["itr_details"] = input("Could you provide your latest ITR details? ")
    else:
        user_responses["itr_details"] = "None"

    user_responses["profession"] = input("What is your profession? ")

    if user_responses["profession"].strip().lower() == "business":
        user_responses["annual_turnover"] = input("Could you provide the annual turnover based on GST records? ")
    elif user_responses["profession"].strip().lower() == "salaried":
        user_responses["annual_salary"] = input("What is your annual salary as per your salary slips? ")
    else:
        user_responses["annual_turnover"] = "None"
        user_responses["annual_salary"] = "None"

    return user_responses

def main():
    # Simulate conversation and get user responses
    user_responses = simulate_conversation()

    # Extract loan information from user responses
    loan_info_json = {
        "loan_interest": user_responses["loan_interest"],
        "loan_amount": int(user_responses["loan_amount"]),
        "loan_purpose": user_responses["loan_purpose"],
        "itr_status": user_responses["itr_status"],
        "profession": user_responses["profession"],
        "annual_turnover": int(user_responses["annual_turnover"]) if user_responses["annual_turnover"] != "None" else None,
        "annual_salary": int(user_responses["annual_salary"]) if user_responses["annual_salary"] != "None" else None
    }

    # Print JSON information
    print("\nJSON Output:")
    print(json.dumps(loan_info_json, indent=4))

if __name__ == "__main__":
    main()
# Out:
# JSON Output:
# {
#     "loan_interest": "yes",
#     "loan_amount": 5000,
#     "loan_purpose": "CAR",
#     "itr_status": "yes",
#     "profession": "student",
#     "annual_turnover": null,
#     "annual_salary": null
# }

# %%
import json

def simulate_conversation():
    user_responses = {}

    # Ask questions and store user responses
    user_responses["loan_interest"] = input(
        "Are you interested in applying for a loan? (Yes/No) "
    ).strip().lower()
    user_responses["loan_amount"] = input("If yes, what is the desired loan amount? ")
    user_responses["loan_purpose"] = input(
        "What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL) "
    ).strip().upper()
    user_responses["itr_status"] = input(
        "Do you file Income Tax Returns (ITR)? (Yes/No) "
    ).strip().lower()

    if user_responses["itr_status"] == "yes":
        user_responses["itr_details"] = input(
            "Could you provide your latest ITR details? "
        )
    else:
        user_responses["itr_details"] = "None"

    user_responses["profession"] = input("What is your profession? ")

    if user_responses["profession"].strip().lower() == "business":
        user_responses["annual_turnover"] = input(
            "Could you provide the annual turnover based on GST records? "
        )
        user_responses["annual_salary"] = "None"
    elif user_responses["profession"].strip().lower() == "salaried":
        user_responses["annual_salary"] = input(
            "What is your annual salary as per your salary slips? "
        )
        user_responses["annual_turnover"] = "None"
    else:
        user_responses["annual_turnover"] = "None"
        user_responses["annual_salary"] = "None"

    return user_responses

def main():
    # Simulate conversation and get user responses
    user_responses = simulate_conversation()

    # Extract loan information from user responses
    loan_info_json = {
        "loan_interest": user_responses["loan_interest"],
        "loan_amount": int(user_responses["loan_amount"]),
        "loan_purpose": user_responses["loan_purpose"],
        "itr_status": user_responses["itr_status"],
        "profession": user_responses["profession"],
        "annual_turnover": (
            int(user_responses["annual_turnover"])
            if user_responses["annual_turnover"] != "None"
            else None
        ),
        "annual_salary": (
            int(user_responses["annual_salary"])
            if user_responses["annual_salary"] != "None"
            else None
        ),
    }

    # Print JSON information
    print("\nJSON Output:")
    print(json.dumps(loan_info_json, indent=4))

if __name__ == "__main__":
    main()
# Out:
# JSON Output:
# {
#     "loan_interest": "yes",
#     "loan_amount": 5000,
#     "loan_purpose": "CAR",
#     "itr_status": "yes",
#     "profession": "business",
#     "annual_turnover": 5000,
#     "annual_salary": null
# }
