# %%
from langchain import PromptTemplate

template = '''Hello! I'm your AI sales assistant, and I'm here to assist you with your loan application. Let's gather some information to get started:

1. Are you interested in applying for a loan? (Yes/No){loan_interest}
2. If yes, what is the desired loan amount?{loan_amount}
3. What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL){loan_purpose}
4. Do you file Income Tax Returns (ITR)? (Yes/No){itr_status}
5. If yes, could you provide your latest ITR details?{profession}
6. What is your profession?{annual_turnover}
   - If Business, could you provide the annual turnover based on GST records?{annual_salary}
   - If Salaried, what is your annual salary as per your salary slips?{goodbye}

Thank you for providing this information. Once we have all the necessary details, we'll proceed with your loan application. If you have any additional questions or if there's anything else you'd like to discuss, feel free to let me know.

To end our conversation, please type "Goodbye" when you're ready to conclude. Thank you!'''

sales_agent_prompt = PromptTemplate(
    input_variables=["loan_interest", "loan_amount", "loan_purpose", "itr_status", "profession", "annual_turnover", "annual_salary", "goodbye"],
    template=template,
)
# Sample conversation output (replace this with the actual output)
conversation_output = "{'loan_interest': 'Yes', 'loan_amount': '50000', 'loan_purpose': 'PERSONAL', 'itr_status': 'Yes', 'profession': 'Business', 'annual_turnover': '500000', 'annual_salary': None, 'goodbye': 'Goodbye'}"

# Convert the string to a dictionary
output_dict = eval(conversation_output)

# Access the values using dictionary keys
loan_interest = output_dict["loan_interest"]
loan_amount = int(output_dict["loan_amount"])
loan_purpose = output_dict["loan_purpose"]
itr_status = output_dict["itr_status"]
profession = output_dict["profession"]
annual_turnover = int(output_dict["annual_turnover"])
annual_salary = int(output_dict["annual_salary"]) if output_dict["annual_salary"] is not None else None
goodbye = output_dict["goodbye"]

# %%
# Extract information in the form of JSON
loan_info_json = {
    "loan_interest":loan_interest,
    "loan_amount": loan_amount,
    "loan_purpose": loan_purpose,
    "itr_status": itr_status,
    "profession": profession,
    "annual_turnover": annual_turnover,
    "annual_salary": annual_salary,
    "goodbye": goodbye
}

(loan_info_json)
# Out:
# {'loan_interest': 'Yes',
#  'loan_amount': 50000,
#  'loan_purpose': 'PERSONAL',
#  'itr_status': 'Yes',
#  'profession': 'Business',
#  'annual_turnover': 500000,
#  'annual_salary': None,
#  'goodbye': 'Goodbye'}

# %%
from langchain import PromptTemplate
import json

template = '''Hello! I'm your AI sales assistant, and I'm here to assist you with your loan application. Let's gather some information to get started:

1. Are you interested in applying for a loan? (Yes/No){loan_interest}
2. If yes, what is the desired loan amount?{loan_amount}
3. What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL){loan_purpose}
4. Do you file Income Tax Returns (ITR)? (Yes/No){itr_status}
5. If yes, could you provide your latest ITR details?{profession}
6. What is your profession?{annual_turnover}
   - If Business, could you provide the annual turnover based on GST records?{annual_salary}
   - If Salaried, what is your annual salary as per your salary slips?{goodbye}

Thank you for providing this information. Once we have all the necessary details, we'll proceed with your loan application. If you have any additional questions or if there's anything else you'd like to discuss, feel free to let me know.

To end our conversation, please type "Goodbye" when you're ready to conclude. Thank you!'''

sales_agent_prompt = PromptTemplate(
    input_variables=["loan_interest", "loan_amount", "loan_purpose", "itr_status", "profession", "annual_turnover", "annual_salary", "goodbye"],
    template=template,
)

def simulate_conversation():
    user_responses = {}
    for variable in sales_agent_prompt.input_variables:
        user_responses[variable] = input(f"{variable.replace('_', ' ').title()}: ").strip()

    return user_responses

def main():
    print("Simulating conversation with the AI sales assistant:")
    user_input = simulate_conversation()

    # Format the user input for the sales agent prompt
    formatted_input = {key: f'{{{key}}}' for key in sales_agent_prompt.input_variables}
    formatted_input.update(user_input)

    # Use the formatted input to create the final conversation
    conversation = sales_agent_prompt.format(**formatted_input)

    # Print the final conversation
    print("\nFinal Conversation:")
    print(conversation)

    # Extract information in the form of JSON
    loan_info_json = {
        "loan_interest": user_input["loan_interest"],
        "loan_amount": int(user_input["loan_amount"]),
        "loan_purpose": user_input["loan_purpose"],
        "itr_status": user_input["itr_status"],
        "profession": user_input["profession"],
        "annual_turnover": int(user_input["annual_turnover"]),
        "annual_salary": int(user_input["annual_salary"]) if user_input["annual_salary"].lower() != 'none' else None,
        "goodbye": user_input["goodbye"]
    }

    # Print the JSON information
    print("\nJSON Output:")
    print(json.dumps(loan_info_json, indent=4))

if __name__ == "__main__":
    main()
# Out:
# Simulating conversation with the AI sales assistant:
#
# Final Conversation:
# Hello! I'm your AI sales assistant, and I'm here to assist you with your loan application. Let's gather some information to get started:
#
# 1. Are you interested in applying for a loan? (Yes/No)5
# 2. If yes, what is the desired loan amount?40000
# 3. What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL)car
# 4. Do you file Income Tax Returns (ITR)? (Yes/No)yes
# 5. If yes, could you provide your latest ITR details?data engineer
# 6. What is your profession?50000
#    - If Business, could you provide the annual turnover based on GST records?600000
#    - If Salaried, what is your annual salary as per your salary slips?
#
# Thank you for providing this information. Once we have all the necessary details, we'll proceed with your loan application. If you have any additional questions or if there's anything else you'd like to discuss, feel free to let me know.
#
# To end our conversation, please type "Goodbye" when you're ready to conclude. Thank you!
#
# JSON Output:
# {
#     "loan_interest": "5",
#     "loan_amount": 40000,
#     "loan_purpose": "car",
#     "itr_status": "yes",
#     "profession": "data engineer",
#     "annual_turnover": 50000,
#     "annual_salary": 600000,
#     "goodbye": ""
# }

# %%
sales_agent_prompt = PromptTemplate(
    input_variables=["loan_interest", "loan_amount", "loan_purpose", "itr_status", "profession", "annual_turnover", "annual_salary", "goodbye"],
    template=template,
)

def simulate_conversation():
    user_responses = {}
    for variable in sales_agent_prompt.input_variables:
        user_responses[variable]=input(f"{variable.replace('_',' ').title()}:")

    return(user_responses)

# %%
user_responses = {}
for variable in range(len(sales_agent_prompt.input_variables)):
   sales_agent_prompt.input_variables[variable]
   user_responses[variable]=input(f"{variable.replace('_',' ').title()}:")

   print(user_responses)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\project1\Task.ipynb Cell 5 line 4
#       <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> for variable in range(len(sales_agent_prompt.input_variables)):
#       <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a>    sales_agent_prompt.input_variables[variable]
# ----> <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a>    user_responses[variable]=input(f"{variable.replace('_',' ').title()}:")
#       <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a>    print(user_responses)
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\project1\Task.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> for variable in range(len(sales_agent_prompt.input_variables)):
# ----> <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>     variable[0]
#       <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>     sales_agent_prompt.input_variables[variable]
#
# TypeError: 'int' object is not subscriptable

# %%
sales_agent_prompt = PromptTemplate(
    input_variables=["loan_interest", "loan_amount", "loan_purpose", "itr_status", "profession", "annual_turnover", "annual_salary", "goodbye"],
    template=template,
)

def simulate_conversation():
    user_responses = {}
    
    for index, variable in enumerate(sales_agent_prompt.input_variables):
        user_responses[variable] = input(f"{variable.replace('_', ' ').title()}:")
        print(user_responses)
    
    return user_responses

# %%
user_responses
# Out:
# {}

# %%
for variable in enumerate(sales_agent_prompt.input_variables):
    print(variable)
# Out:
# (0, 'annual_salary')
# (1, 'annual_turnover')
# (2, 'goodbye')
# (3, 'itr_status')
# (4, 'loan_amount')
# (5, 'loan_interest')
# (6, 'loan_purpose')
# (7, 'profession')

# %%
from langchain import PromptTemplate
import json

# Define the conversation template
template = '''Hello! I'm your AI sales assistant, and I'm here to assist you with your loan application. Let's gather some information to get started:

1. Are you interested in applying for a loan? (Yes/No){loan_interest}
2. If yes, what is the desired loan amount?{loan_amount}
3. What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL){loan_purpose}
4. Do you file Income Tax Returns (ITR)? (Yes/No){itr_status}
5. If yes, could you provide your latest ITR details?{itr_deatils}
6. What is your profession?{profession}
   - If Business, could you provide the annual turnover based on GST records?{annual_turnover}
   - If Salaried, what is your annual salary as per your salary slips?{annual_salary}

Thank you for providing this information. Once we have all the necessary details, we'll proceed with your loan application. If you have any additional questions or if there's anything else you'd like to discuss, feel free to let me know.

To end our conversation, please type "Goodbye" when you're ready to conclude. Thank you!'''

# Create a PromptTemplate
sales_agent_prompt = PromptTemplate(
    input_variables=["loan_interest", "loan_amount", "loan_purpose", "itr_status", "profession", "annual_turnover", "annual_salary", "goodbye"],
    template=template,
)

# Function to simulate a conversation with the AI sales assistant
def simulate_conversation():
    user_responses = {}
    
    # Follow the fixed sequence of questions
    questions = [
        " Are you interested in applying for a loan? (Yes/No)", "If yes, what is the desired loan amount?", "What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL)", "Do you file Income Tax Returns (ITR)? (Yes/No)", " If yes, could you provide your latest ITR details?", "What is your profession?", "If Salaried, what is your annual salary as per your salary slips?", "goodbye"
    ]

    for variable in questions:
        user_responses[variable] = input(f"{variable.replace('_', ' ').title()}: ").strip()

    return user_responses

# Main function
def main():
    print("Simulating conversation with the AI sales assistant:")
    user_input = simulate_conversation()

    # Format the user input for the sales agent prompt
    formatted_input = {key: f'{{{key}}}' for key in sales_agent_prompt.input_variables}
    formatted_input.update(user_input)

    # Use the formatted input to create the final conversation
    conversation = sales_agent_prompt.format(**formatted_input)

    # Print the final conversation
    print("\nFinal Conversation:")
    print(conversation)

    # Extract information in the form of JSON
    loan_info_json = {
        "loan_interest": user_input["loan_interest"],
        "loan_amount": int(user_input["loan_amount"]),
        "loan_purpose": user_input["loan_purpose"],
        "itr_status": user_input["itr_status"],
        "profession": user_input["profession"],
        "annual_turnover": int(user_input["annual_turnover"]),
        "annual_salary": int(user_input["annual_salary"]) if user_input["annual_salary"].lower() != 'none' else None,
        "goodbye": user_input["goodbye"]
    }

    # Print the JSON information
    print("\nJSON Output:")
    print(json.dumps(loan_info_json, indent=4))

if __name__ == "__main__":
    main()
# Out:
# Simulating conversation with the AI sales assistant:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\project1\Task.ipynb Cell 10 line 7
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X12sZmlsZQ%3D%3D?line=69'>70</a>     print(json.dumps(loan_info_json, indent=4))
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X12sZmlsZQ%3D%3D?line=71'>72</a> if __name__ == "__main__":
# ---> <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X12sZmlsZQ%3D%3D?line=72'>73</a>     main()
#
# d:\project1\Task.ipynb Cell 10 line 5
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X12sZmlsZQ%3D%3D?line=46'>47</a> formatted_input.update(user_input)
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X12sZmlsZQ%3D%3D?line=48'>49</a> # Use the formatted input to create the final conversation
# ---> <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X12sZmlsZQ%3D%3D?line=49'>50</a> conversation = sales_agent_prompt.format(**formatted_input)
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X12sZmlsZQ%3D%3D?line=51'>52</a> # Print the final conversation
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X12sZmlsZQ%3D%3D?line=52'>53</a> print("\nFinal Conversation:")
#
# File d:\project1\venv\Lib\site-packages\langchain_core\prompts\prompt.py:126, in PromptTemplate.format(self, **kwargs)
#     111 """Format the prompt with the inputs.
#     112
#     113 Args:
#    (...)
#     123         prompt.format(variable1="foo")
#     124 """
#     125 kwargs = self._merge_partial_and_user_variables(**kwargs)
# --> 126 return DEFAULT_FORMATTER_MAPPING[self.template_format](self.template, **kwargs)
#
# File C:\animesh\Lib\string.py:190, in Formatter.format(self, format_string, *args, **kwargs)
#     189 def format(self, format_string, /, *args, **kwargs):
# --> 190     return self.vformat(format_string, args, kwargs)
#
# File d:\project1\venv\Lib\site-packages\langchain_core\utils\formatting.py:29, in StrictFormatter.vformat(self, format_string, args, kwargs)
#      24 if len(args) > 0:
#      25     raise ValueError(
#      26         "No arguments should be provided, "
#      27         "everything should be passed as keyword arguments."
#      28     )
# ---> 29 return super().vformat(format_string, args, kwargs)
#
# File C:\animesh\Lib\string.py:195, in Formatter.vformat(self, format_string, args, kwargs)
#     193 used_args = set()
#     194 result, _ = self._vformat(format_string, args, kwargs, used_args, 2)
# --> 195 self.check_unused_args(used_args, args, kwargs)
#     196 return result
#
# File d:\project1\venv\Lib\site-packages\langchain_core\utils\formatting.py:18, in StrictFormatter.check_unused_args(self, used_args, args, kwargs)
#      16 extra = set(kwargs).difference(used_args)
#      17 if extra:
# ---> 18     raise KeyError(extra)
#
# KeyError: {' Are you interested in applying for a loan? (Yes/No)'}

# %%
from langchain import PromptTemplate
import json

# Define the conversation template
template = '''Hello! I'm your AI sales assistant, and I'm here to assist you with your loan application. 
Let's gather some information to get started:

1. Are you interested in applying for a loan? (Yes/No){loan_interest}
2. If yes, what is the desired loan amount?{loan_amount}
3. What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL){loan_purpose}
4. Do you file Income Tax Returns (ITR)? (Yes/No){itr_status}
5. If yes, could you provide your latest ITR details?{itr_deatils}
6. What is your profession?{profession}
   - If Business, could you provide the annual turnover based on GST records?{annual_turnover}
   - If Salaried, what is your annual salary as per your salary slips?{annual_salary}

Thank you for providing this information. Once we have all the necessary details,
we'll proceed with your loan application.
 If you have any additional questions or if there's anything else you'd like to discuss, feel free to let me know.

To end our conversation, please type "Goodbye" when you're ready to conclude. Thank you!'''

# Create a PromptTemplate
sales_agent_prompt = PromptTemplate(
    input_variables=["loan_interest", 
                     "loan_amount", 
                     "loan_purpose", 
                     "itr_status", "itr_deatils"
                     ,"profession", "annual_turnover", 
                     "annual_salary"],
    template=template,
)

# Function to simulate a conversation with the AI sales assistant
def simulate_conversation():
    user_responses = {}
    
    # Follow the fixed sequence of questions
    questions = [
        " Are you interested in applying for a loan? (Yes/No)",
        "If yes, what is the desired loan amount?", 
        "What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL)", 
        "Do you file Income Tax Returns (ITR)? (Yes/No)", 
        " If yes, could you provide your latest ITR details?", 
        "What is your profession?", 
        "If Business, could you provide the annual turnover based on GST records?",
        "If Salaried, what is your annual salary as per your salary slips?", 
        
    ]

    for variable in questions:
        user_responses[variable] = input(f"{variable.replace('_', ' ').title()}: ").strip()

    return user_responses

# Main function
def main():
    print("Simulating conversation with the AI sales assistant:")
    user_input = simulate_conversation()

    # Format the user input for the sales agent prompt
    formatted_input = {key: f'{{{key}}}' for key in sales_agent_prompt.input_variables}
    formatted_input.update(user_input)

    # Use the formatted input to create the final conversation
    conversation = sales_agent_prompt.format(**formatted_input)

    # Print the final conversation
    print("\nFinal Conversation:")
    print(conversation)

    # Extract information in the form of JSON
    loan_info_json = {
        "loan_interest": user_input["loan_interest"],
        "loan_amount": int(user_input["loan_amount"]),
        "loan_purpose": user_input["loan_purpose"],
        "itr_status": user_input["itr_status"],
        "profession": user_input["profession"],
        "annual_turnover": int(user_input["annual_turnover"]),
        "annual_salary": int(user_input["annual_salary"]) if user_input["annual_salary"].lower() != 'none' else None,
        "goodbye": user_input["goodbye"]
    }

    # Print the JSON information
    print("\nJSON Output:")
    print(json.dumps(loan_info_json, indent=4))

if __name__ == "__main__":
    main()
# Out:
# Simulating conversation with the AI sales assistant:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\project1\Task.ipynb Cell 11 line 8
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X13sZmlsZQ%3D%3D?line=85'>86</a>     print(json.dumps(loan_info_json, indent=4))
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X13sZmlsZQ%3D%3D?line=87'>88</a> if __name__ == "__main__":
# ---> <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X13sZmlsZQ%3D%3D?line=88'>89</a>     main()
#
# d:\project1\Task.ipynb Cell 11 line 6
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X13sZmlsZQ%3D%3D?line=62'>63</a> formatted_input.update(user_input)
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X13sZmlsZQ%3D%3D?line=64'>65</a> # Use the formatted input to create the final conversation
# ---> <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X13sZmlsZQ%3D%3D?line=65'>66</a> conversation = sales_agent_prompt.format(**formatted_input)
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X13sZmlsZQ%3D%3D?line=67'>68</a> # Print the final conversation
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X13sZmlsZQ%3D%3D?line=68'>69</a> print("\nFinal Conversation:")
#
# File d:\project1\venv\Lib\site-packages\langchain_core\prompts\prompt.py:126, in PromptTemplate.format(self, **kwargs)
#     111 """Format the prompt with the inputs.
#     112
#     113 Args:
#    (...)
#     123         prompt.format(variable1="foo")
#     124 """
#     125 kwargs = self._merge_partial_and_user_variables(**kwargs)
# --> 126 return DEFAULT_FORMATTER_MAPPING[self.template_format](self.template, **kwargs)
#
# File C:\animesh\Lib\string.py:190, in Formatter.format(self, format_string, *args, **kwargs)
#     189 def format(self, format_string, /, *args, **kwargs):
# --> 190     return self.vformat(format_string, args, kwargs)
#
# File d:\project1\venv\Lib\site-packages\langchain_core\utils\formatting.py:29, in StrictFormatter.vformat(self, format_string, args, kwargs)
#      24 if len(args) > 0:
#      25     raise ValueError(
#      26         "No arguments should be provided, "
#      27         "everything should be passed as keyword arguments."
#      28     )
# ---> 29 return super().vformat(format_string, args, kwargs)
#
# File C:\animesh\Lib\string.py:195, in Formatter.vformat(self, format_string, args, kwargs)
#     193 used_args = set()
#     194 result, _ = self._vformat(format_string, args, kwargs, used_args, 2)
# --> 195 self.check_unused_args(used_args, args, kwargs)
#     196 return result
#
# File d:\project1\venv\Lib\site-packages\langchain_core\utils\formatting.py:18, in StrictFormatter.check_unused_args(self, used_args, args, kwargs)
#      16 extra = set(kwargs).difference(used_args)
#      17 if extra:
# ---> 18     raise KeyError(extra)
#
# KeyError: {' If yes, could you provide your latest ITR details?', 'If Business, could you provide the annual turnover based on GST records?', 'What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL)', ' Are you interested in applying for a loan? (Yes/No)', 'Do you file Income Tax Returns (ITR)? (Yes/No)', 'If yes, what is the desired loan amount?', 'If Salaried, what is your annual salary as per your salary slips?', 'What is your profession?'}

# %%
from langchain import PromptTemplate
import json

# Define the conversation template
template = '''Hello! I'm your AI sales assistant, and I'm here to assist you with your loan application. 
Let's gather some information to get started:

1. Are you interested in applying for a loan? (Yes/No){loan_interest}
2. If yes, what is the desired loan amount?{loan_amount}
3. What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL){loan_purpose}
4. Do you file Income Tax Returns (ITR)? (Yes/No){itr_status}
5. If yes, could you provide your latest ITR details?{itr_details}
6. What is your profession?{profession}
   - If Business, could you provide the annual turnover based on GST records?{annual_turnover}
   - If Salaried, what is your annual salary as per your salary slips?{annual_salary}

Thank you for providing this information. Once we have all the necessary details,
we'll proceed with your loan application.
 If you have any additional questions or if there's anything else you'd like to discuss, feel free to let me know.

To end our conversation, please type "Goodbye" when you're ready to conclude. Thank you!'''

# Create a PromptTemplate
sales_agent_prompt = PromptTemplate(
    input_variables=["loan_interest", 
                     "loan_amount", 
                     "loan_purpose", 
                     "itr_status", 
                     "itr_details",
                     "profession", 
                     "annual_turnover", 
                     "annual_salary"],
    template=template,
)

# Function to simulate a conversation with the AI sales assistant
def simulate_conversation():
    user_responses = {}
    
    # Follow the fixed sequence of questions
    questions = [
        "Are you interested in applying for a loan? (Yes/No)",
        "If yes, what is the desired loan amount?", 
        "What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL)", 
        "Do you file Income Tax Returns (ITR)? (Yes/No)", 
        "If yes, could you provide your latest ITR details?", 
        "What is your profession?", 
        "If Business, could you provide the annual turnover based on GST records?",
        "If Salaried, what is your annual salary as per your salary slips?", 
    ]

    for variable in questions:
        user_responses[variable] = input(f"{variable.replace('_', ' ').title()}: ").strip()

    return user_responses

# Main function
def main():
    print("Simulating conversation with the AI sales assistant:")
    user_input = simulate_conversation()

    # Format the user input for the sales agent prompt
    formatted_input = {key: f'{{{key}}}' for key in sales_agent_prompt.input_variables}
    formatted_input.update(user_input)

    # Use the formatted input to create the final conversation
    conversation = sales_agent_prompt.format(**formatted_input)

    # Print the final conversation
    print("\nFinal Conversation:")
    print(conversation)

    # Extract information in the form of JSON
    loan_info_json = {
        "loan_interest": user_input["loan_interest"],
        "loan_amount": int(user_input["loan_amount"]),
        "loan_purpose": user_input["loan_purpose"],
        "itr_status": user_input["itr_status"],
        "itr_details": user_input["itr_details"] if user_input["itr_status"].lower() == 'yes' else None,
        "profession": user_input["profession"],
        "annual_turnover": int(user_input["annual_turnover"]) if 'business' in user_input["profession"].lower() else None,
        "annual_salary": int(user_input["annual_salary"]) if 'salaried' in user_input["profession"].lower() else None,
        "goodbye": user_input["goodbye"] if "goodbye" in user_input else None,
    }

    # Print the JSON information
    print("\nJSON Output:")
    print(json.dumps(loan_info_json, indent=4))

if __name__ == "__main__":
    main()
# Out:
# Simulating conversation with the AI sales assistant:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\project1\Task.ipynb Cell 12 line 9
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X14sZmlsZQ%3D%3D?line=87'>88</a>     print(json.dumps(loan_info_json, indent=4))
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X14sZmlsZQ%3D%3D?line=89'>90</a> if __name__ == "__main__":
# ---> <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X14sZmlsZQ%3D%3D?line=90'>91</a>     main()
#
# d:\project1\Task.ipynb Cell 12 line 6
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X14sZmlsZQ%3D%3D?line=63'>64</a> formatted_input.update(user_input)
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X14sZmlsZQ%3D%3D?line=65'>66</a> # Use the formatted input to create the final conversation
# ---> <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X14sZmlsZQ%3D%3D?line=66'>67</a> conversation = sales_agent_prompt.format(**formatted_input)
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X14sZmlsZQ%3D%3D?line=68'>69</a> # Print the final conversation
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X14sZmlsZQ%3D%3D?line=69'>70</a> print("\nFinal Conversation:")
#
# File d:\project1\venv\Lib\site-packages\langchain_core\prompts\prompt.py:126, in PromptTemplate.format(self, **kwargs)
#     111 """Format the prompt with the inputs.
#     112
#     113 Args:
#    (...)
#     123         prompt.format(variable1="foo")
#     124 """
#     125 kwargs = self._merge_partial_and_user_variables(**kwargs)
# --> 126 return DEFAULT_FORMATTER_MAPPING[self.template_format](self.template, **kwargs)
#
# File C:\animesh\Lib\string.py:190, in Formatter.format(self, format_string, *args, **kwargs)
#     189 def format(self, format_string, /, *args, **kwargs):
# --> 190     return self.vformat(format_string, args, kwargs)
#
# File d:\project1\venv\Lib\site-packages\langchain_core\utils\formatting.py:29, in StrictFormatter.vformat(self, format_string, args, kwargs)
#      24 if len(args) > 0:
#      25     raise ValueError(
#      26         "No arguments should be provided, "
#      27         "everything should be passed as keyword arguments."
#      28     )
# ---> 29 return super().vformat(format_string, args, kwargs)
#
# File C:\animesh\Lib\string.py:195, in Formatter.vformat(self, format_string, args, kwargs)
#     193 used_args = set()
#     194 result, _ = self._vformat(format_string, args, kwargs, used_args, 2)
# --> 195 self.check_unused_args(used_args, args, kwargs)
#     196 return result
#
# File d:\project1\venv\Lib\site-packages\langchain_core\utils\formatting.py:18, in StrictFormatter.check_unused_args(self, used_args, args, kwargs)
#      16 extra = set(kwargs).difference(used_args)
#      17 if extra:
# ---> 18     raise KeyError(extra)
#
# KeyError: {'If Business, could you provide the annual turnover based on GST records?', 'What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL)', 'Are you interested in applying for a loan? (Yes/No)', 'If yes, could you provide your latest ITR details?', 'Do you file Income Tax Returns (ITR)? (Yes/No)', 'If yes, what is the desired loan amount?', 'If Salaried, what is your annual salary as per your salary slips?', 'What is your profession?'}

# %%
from langchain import PromptTemplate
import json

# Define the conversation template
template = '''Hello! I'm your AI sales assistant, and I'm here to assist you with your loan application. Let's gather some information to get started:

1. Are you interested in applying for a loan? (Yes/No){loan_interest}
2. If yes, what is the desired loan amount?{loan_amount}
3. What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL){loan_purpose}
4. Do you file Income Tax Returns (ITR)? (Yes/No){itr_status}
5. If yes, could you provide your latest ITR details?{profession}
6. What is your profession?{annual_turnover}
   - If Business, could you provide the annual turnover based on GST records?{annual_salary}
   - If Salaried, what is your annual salary as per your salary slips?{goodbye}

Thank you for providing this information. Once we have all the necessary details, we'll proceed with your loan application. If you have any additional questions or if there's anything else you'd like to discuss, feel free to let me know.

To end our conversation, please type "Goodbye" when you're ready to conclude. Thank you!'''

# Create a PromptTemplate
sales_agent_prompt = PromptTemplate(
    input_variables=["loan_interest", "loan_amount", "loan_purpose", "itr_status", "profession", "annual_turnover", "annual_salary", "goodbye"],
    template=template,
)

# Function to simulate a conversation with the AI sales assistant
def simulate_conversation():
    user_responses = {}
    
    # Follow the fixed sequence of questions
    questions = {
        "loan_interest", "loan_amount", "loan_purpose", "itr_status", "profession", "annual_turnover", "annual_salary", "goodbye"
    }

    for variable in questions:
        user_responses[variable] = input(f"{variable.replace('_', ' ').title()}: ").strip()

    return user_responses

# Main function
def main():
    print("Simulating conversation with the AI sales assistant:")
    user_input = simulate_conversation()

    # Format the user input for the sales agent prompt
    formatted_input = {key: f'{{{key}}}' for key in sales_agent_prompt.input_variables}
    formatted_input.update(user_input)

    # Use the formatted input to create the final conversation
    conversation = sales_agent_prompt.format(**formatted_input)

    # Print the final conversation
    print("\nFinal Conversation:")
    print(conversation)

    # Extract information in the form of JSON
    loan_info_json = {
        "loan_interest": user_input["loan_interest"],
        "loan_amount": int(user_input["loan_amount"]),
        "loan_purpose": user_input["loan_purpose"],
        "itr_status": user_input["itr_status"],
        "profession": user_input["profession"],
        "annual_turnover": int(user_input["annual_turnover"]),
        "annual_salary": int(user_input["annual_salary"]) if user_input["annual_salary"].lower() != 'none' else None,
        "goodbye": user_input["goodbye"]
    }

    # Print the JSON information
    print("\nJSON Output:")
    print(json.dumps(loan_info_json, indent=4))

if __name__ == "__main__":
    main()
# Out:
# Simulating conversation with the AI sales assistant:
#
# Final Conversation:
# Hello! I'm your AI sales assistant, and I'm here to assist you with your loan application. Let's gather some information to get started:
#
# 1. Are you interested in applying for a loan? (Yes/No)yes
# 2. If yes, what is the desired loan amount?5000
# 3. What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL)454554
# 4. Do you file Income Tax Returns (ITR)? (Yes/No)465465
# 5. If yes, could you provide your latest ITR details?65465
# 6. What is your profession?6546
#    - If Business, could you provide the annual turnover based on GST records?465
#    - If Salaried, what is your annual salary as per your salary slips?654
#
# Thank you for providing this information. Once we have all the necessary details, we'll proceed with your loan application. If you have any additional questions or if there's anything else you'd like to discuss, feel free to let me know.
#
# To end our conversation, please type "Goodbye" when you're ready to conclude. Thank you!
#
# JSON Output:
# {
#     "loan_interest": "yes",
#     "loan_amount": 5000,
#     "loan_purpose": "454554",
#     "itr_status": "465465",
#     "profession": "65465",
#     "annual_turnover": 6546,
#     "annual_salary": 465,
#     "goodbye": "654"
# }

# %%
from langchain import PromptTemplate
import json

# Define the conversation template
template = '''Hello! I'm your AI sales assistant, and I'm here to assist you with your loan application. Let's gather some information to get started:

1. Are you interested in applying for a loan? (Yes/No){loan_interest}
2. If yes, what is the desired loan amount?{loan_amount}
3. What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL){loan_purpose}
4. Do you file Income Tax Returns (ITR)? (Yes/No){itr_status}
5. If yes, could you provide your latest ITR details?{profession}
6. What is your profession?{annual_turnover}
   - If Business, could you provide the annual turnover based on GST records?{annual_salary}
   - If Salaried, what is your annual salary as per your salary slips?{goodbye}

Thank you for providing this information. Once we have all the necessary details, we'll proceed with your loan application. If you have any additional questions or if there's anything else you'd like to discuss, feel free to let me know.

To end our conversation, please type "Goodbye" when you're ready to conclude. Thank you!'''

# Create a PromptTemplate
sales_agent_prompt = PromptTemplate(
    input_variables=["loan_interest", "loan_amount", "loan_purpose", "itr_status", "profession", "annual_turnover", "annual_salary", "goodbye"],
    template=template,
)
# Function to simulate a conversation with the AI sales assistant
def simulate_conversation():
    user_responses = {}

    for variable in sales_agent_prompt.input_variables:
        # Display the question associated with the current variable
        question = template.split(f"{{{variable}}}")[0].split(str(sales_agent_prompt.input_variables.index(variable) + 1) + ". ")[1]
        user_responses[variable] = input(f"{question.strip()}: ").strip()

    return user_responses


# Main function
def main():
    print("Simulating conversation with the AI sales assistant:")
    user_input = simulate_conversation()

    # Format the user input for the sales agent prompt
    formatted_input = {key: f'{{{key}}}' for key in sales_agent_prompt.input_variables}
    formatted_input.update(user_input)

    # Use the formatted input to create the final conversation
    conversation = sales_agent_prompt.format(**formatted_input)

    # Print the final conversation
    print("\nFinal Conversation:")
    print(conversation)

    # Extract information in the form of JSON
    loan_info_json = {
        "loan_interest": user_input["loan_interest"],
        "loan_amount": int(user_input["loan_amount"]),
        "loan_purpose": user_input["loan_purpose"],
        "itr_status": user_input["itr_status"],
        "profession": user_input["profession"],
        "annual_turnover": int(user_input["annual_turnover"]),
        "annual_salary": int(user_input["annual_salary"]) if user_input["annual_salary"].lower() != 'none' else None,
        "goodbye": user_input["goodbye"]
    }

    # Print the JSON information
    print("\nJSON Output:")
    print(json.dumps(loan_info_json, indent=4))

if __name__ == "__main__":
    main()
# Out:
# Simulating conversation with the AI sales assistant:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\project1\Task.ipynb Cell 14 line 7
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X16sZmlsZQ%3D%3D?line=66'>67</a>     print(json.dumps(loan_info_json, indent=4))
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X16sZmlsZQ%3D%3D?line=68'>69</a> if __name__ == "__main__":
# ---> <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X16sZmlsZQ%3D%3D?line=69'>70</a>     main()
#
# d:\project1\Task.ipynb Cell 14 line 4
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X16sZmlsZQ%3D%3D?line=37'>38</a> def main():
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X16sZmlsZQ%3D%3D?line=38'>39</a>     print("Simulating conversation with the AI sales assistant:")
# ---> <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X16sZmlsZQ%3D%3D?line=39'>40</a>     user_input = simulate_conversation()
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X16sZmlsZQ%3D%3D?line=41'>42</a>     # Format the user input for the sales agent prompt
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X16sZmlsZQ%3D%3D?line=42'>43</a>     formatted_input = {key: f'{{{key}}}' for key in sales_agent_prompt.input_variables}
#
# d:\project1\Task.ipynb Cell 14 line 3
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X16sZmlsZQ%3D%3D?line=26'>27</a> user_responses = {}
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X16sZmlsZQ%3D%3D?line=28'>29</a> for variable in sales_agent_prompt.input_variables:
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X16sZmlsZQ%3D%3D?line=29'>30</a>     # Display the question associated with the current variable
# ---> <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X16sZmlsZQ%3D%3D?line=30'>31</a>     question = template.split(f"{{{variable}}}")[0].split(str(sales_agent_prompt.input_variables.index(variable) + 1) + ". ")[1]
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X16sZmlsZQ%3D%3D?line=31'>32</a>     user_responses[variable] = input(f"{question.strip()}: ").strip()
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X16sZmlsZQ%3D%3D?line=33'>34</a> return user_responses
#
# IndexError: list index out of range

# %%
from langchain import PromptTemplate
import json

# Define the conversation template
template = '''Hello! I'm your AI sales assistant, and I'm here to assist you with your loan application. Let's gather some information to get started:

1. Are you interested in applying for a loan? (Yes/No){loan_interest}
2. If yes, what is the desired loan amount?{loan_amount}
3. What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL){loan_purpose}
4. Do you file Income Tax Returns (ITR)? (Yes/No){itr_status}
5. If yes, could you provide your latest ITR details?{profession}
6. What is your profession?{annual_turnover}
   - If Business, could you provide the annual turnover based on GST records?{annual_salary}
   - If Salaried, what is your annual salary as per your salary slips?{goodbye}

Thank you for providing this information. Once we have all the necessary details, we'll proceed with your loan application. If you have any additional questions or if there's anything else you'd like to discuss, feel free to let me know.

To end our conversation, please type "Goodbye" when you're ready to conclude. Thank you!'''

# Create a PromptTemplate
sales_agent_prompt = PromptTemplate(
    input_variables=["loan_interest", "loan_amount", "loan_purpose", "itr_status", "profession", "annual_turnover", "annual_salary", "goodbye"],
    template=template,
)

# Function to simulate a conversation with the AI sales assistant
def simulate_conversation():
    user_responses = {}
    
    # Follow the fixed sequence of questions
    questions = {
        "loan_interest", "loan_amount", "loan_purpose", "itr_status", "profession", "annual_turnover", "annual_salary", "goodbye"
    }

    for variable in questions:
        user_responses[variable] = input(f"{variable.replace('_', ' ').title()}: ").strip()

    return user_responses

# Main function
def main():
    print("Simulating conversation with the AI sales assistant:")
    user_input = simulate_conversation()

    # Format the user input for the sales agent prompt
    formatted_input = {key: f'{{{key}}}' for key in sales_agent_prompt.input_variables}
    formatted_input.update(user_input)

    # Use the formatted input to create the final conversation
    conversation = sales_agent_prompt.format(**formatted_input)

    # Print the final conversation
    print("\nFinal Conversation:")
    print(conversation)

    # Extract information in the form of JSON
    loan_info_json = {
        "loan_interest": user_input["loan_interest"],
        "loan_amount": int(user_input["loan_amount"]),
        "loan_purpose": user_input["loan_purpose"],
        "itr_status": user_input["itr_status"],
        "profession": user_input["profession"],
        "annual_turnover": int(user_input["annual_turnover"]),
        "annual_salary": int(user_input["annual_salary"]) if user_input["annual_salary"].lower() != 'none' else None,
        "goodbye": user_input["goodbye"]
    }

    # Print the JSON information
    print("\nJSON Output:")
    print(json.dumps(loan_info_json, indent=4))

if __name__ == "__main__":
    main()
# Out:
# Simulating conversation with the AI sales assistant:
#
# Final Conversation:
# Hello! I'm your AI sales assistant, and I'm here to assist you with your loan application. Let's gather some information to get started:
#
# 1. Are you interested in applying for a loan? (Yes/No)
# 2. If yes, what is the desired loan amount?
# 3. What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL)
# 4. Do you file Income Tax Returns (ITR)? (Yes/No)
# 5. If yes, could you provide your latest ITR details?
# 6. What is your profession?
#    - If Business, could you provide the annual turnover based on GST records?
#    - If Salaried, what is your annual salary as per your salary slips?gii
#
# Thank you for providing this information. Once we have all the necessary details, we'll proceed with your loan application. If you have any additional questions or if there's anything else you'd like to discuss, feel free to let me know.
#
# To end our conversation, please type "Goodbye" when you're ready to conclude. Thank you!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\project1\Task.ipynb Cell 15 line 7
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X20sZmlsZQ%3D%3D?line=69'>70</a>     print(json.dumps(loan_info_json, indent=4))
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X20sZmlsZQ%3D%3D?line=71'>72</a> if __name__ == "__main__":
# ---> <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X20sZmlsZQ%3D%3D?line=72'>73</a>     main()
#
# d:\project1\Task.ipynb Cell 15 line 5
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X20sZmlsZQ%3D%3D?line=53'>54</a> print(conversation)
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X20sZmlsZQ%3D%3D?line=55'>56</a> # Extract information in the form of JSON
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X20sZmlsZQ%3D%3D?line=56'>57</a> loan_info_json = {
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X20sZmlsZQ%3D%3D?line=57'>58</a>     "loan_interest": user_input["loan_interest"],
# ---> <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X20sZmlsZQ%3D%3D?line=58'>59</a>     "loan_amount": int(user_input["loan_amount"]),
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X20sZmlsZQ%3D%3D?line=59'>60</a>     "loan_purpose": user_input["loan_purpose"],
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X20sZmlsZQ%3D%3D?line=60'>61</a>     "itr_status": user_input["itr_status"],
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X20sZmlsZQ%3D%3D?line=61'>62</a>     "profession": user_input["profession"],
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X20sZmlsZQ%3D%3D?line=62'>63</a>     "annual_turnover": int(user_input["annual_turnover"]),
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X20sZmlsZQ%3D%3D?line=63'>64</a>     "annual_salary": int(user_input["annual_salary"]) if user_input["annual_salary"].lower() != 'none' else None,
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X20sZmlsZQ%3D%3D?line=64'>65</a>     "goodbye": user_input["goodbye"]
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X20sZmlsZQ%3D%3D?line=65'>66</a> }
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X20sZmlsZQ%3D%3D?line=67'>68</a> # Print the JSON information
#      <a href='vscode-notebook-cell:/d%3A/project1/Task.ipynb#X20sZmlsZQ%3D%3D?line=68'>69</a> print("\nJSON Output:")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
from langchain import PromptTemplate
import json

# Define the conversation template
template = '''Hello! I'm your AI sales assistant, and I'm here to assist you with your loan application. Let's gather some information to get started:

1. Are you interested in applying for a loan? (Yes/No){loan_interest}
2. If yes, what is the desired loan amount?{loan_amount}
3. What is the purpose of the loan? (CAR/HOME/BUSINESS/PERSONAL){loan_purpose}
4. Do you file Income Tax Returns (ITR)? (Yes/No){itr_status}
5. If yes, could you provide your latest ITR details?{profession}
6. What is your profession?{annual_turnover}
   - If Business, could you provide the annual turnover based on GST records?{annual_salary}
   - If Salaried, what is your annual salary as per your salary slips?{goodbye}

Thank you for providing this information. Once we have all the necessary details, we'll proceed with your loan application. If you have any additional questions or if there's anything else you'd like to discuss, feel free to let me know.

To end our conversation, please type "Goodbye" when you're ready to conclude. Thank you!'''

# Create a PromptTemplate
sales_agent_prompt = PromptTemplate(
    input_variables=["loan_interest", "loan_amount", "loan_purpose", "itr_status", "profession", "annual_turnover", "annual_salary", "goodbye"],
    template=template,
)

# Function to simulate a conversation with the AI sales assistant
def simulate_conversation():
    user_responses = {}
    
    # Follow the fixed sequence of questions
    questions = {
        "loan_interest", "loan_amount", "loan_purpose", "itr_status", "profession", "annual_turnover", "annual_salary", "goodbye"
    }

    for variable in questions:
        user_responses[variable] = input(f"{variable.replace('_', ' ').title()}: ").strip()

    return user_responses

# Main function
def main():
    print("Simulating conversation with the AI sales assistant:")
    user_input = simulate_conversation()

    # Format the user input for the sales agent prompt
    formatted_input = {key: f'{{{key}}}' for key in sales_agent_prompt.input_variables}
    formatted_input.update(user_input)

    # Use the formatted input to create the final conversation
    conversation = sales_agent_prompt.format(**formatted_input)

    # Print the final conversation
    print("\nFinal Conversation:")
    print(conversation)

    # Extract information in the form of JSON
    loan_info_json = {
        "loan_interest": user_input["loan_interest"],
        "loan_amount": int(user_input["loan_amount"]),
        "loan_purpose": user_input["loan_purpose"],
        "itr_status": user_input["itr_status"],
        "profession": user_input["profession"],
        "annual_turnover": int(user_input["annual_turnover"]),
        "annual_salary": int(user_input["annual_salary"]) if user_input["annual_salary"].lower() != 'none' else None,
        "goodbye": user_input["goodbye"]
    }

    # Print the JSON information
    print("\nJSON Output:")
    print(json.dumps(loan_info_json, indent=4))

if __name__ == "__main__":
    main()
# Out:
# Simulating conversation with the AI sales assistant:

# %%
e
